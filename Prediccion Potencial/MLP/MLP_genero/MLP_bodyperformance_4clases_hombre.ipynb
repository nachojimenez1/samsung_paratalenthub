# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv('bodyPerformance.csv')

# Ingeniería de variables
df['bmi'] = df['weight_kg'] / ((df['height_cm'] / 100) ** 2)
df['relative_grip'] = df['gripForce'] / df['weight_kg']

# Quitamos a las mujeres del dataset para comparar hombres
df = df[df['gender'] != 'F']
df.drop(columns=['gender'], inplace=True)

# Dividimos entre datos y objetivo
X = df.drop('class', axis=1)
y = df['class']

# %%
matriz_corr = df.drop(columns=['class']).corr()
plt.figure(figsize=(14, 10))
sns.heatmap(matriz_corr, 
            annot=True,
            fmt=".2f",
            cmap="coolwarm",
            vmin=-1, vmax=1,
            linewidths=0.5,
            square=True)
plt.title('Matriz de Correlación del Dataset Body Performance', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Cambiamos de categorico a enteros los objetivos
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Separamos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Escalamos los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Diseñamos la arquitectura de la red MLP
model = Sequential([
    Dense(1024, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    Dense(4, activation='softmax')
])
# Out:
# c:\Users\miguelmr\anaconda3\envs\general\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Modificamos el learning rate si se estanca el aprendizaje
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)

# Paramos si hay sobreajuste
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

# Entrenamos la red
history = model.fit(X_train_scaled,
                    y_train,
                    epochs=200,
                    batch_size=32,
                    validation_split=0.1,
                    callbacks=[reduce_lr, early_stop],
                    verbose=1)
# Out:
# Epoch 1/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5001 - loss: 1.2970 - val_accuracy: 0.3791 - val_loss: 1.2929 - learning_rate: 0.0010
# Epoch 2/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5723 - loss: 0.9882 - val_accuracy: 0.5442 - val_loss: 0.9501 - learning_rate: 0.0010
# Epoch 3/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6094 - loss: 0.9181 - val_accuracy: 0.6401 - val_loss: 0.7764 - learning_rate: 0.0010
# Epoch 4/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6226 - loss: 0.8688 - val_accuracy: 0.7035 - val_loss: 0.6962 - learning_rate: 0.0010
# Epoch 5/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6454 - loss: 0.8275 - val_accuracy: 0.7006 - val_loss: 0.6961 - learning_rate: 0.0010
# Epoch 6/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6510 - loss: 0.8031 - val_accuracy: 0.6814 - val_loss: 0.7257 - learning_rate: 0.0010
# Epoch 7/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6564 - loss: 0.8011 - val_accuracy: 0.7050 - val_loss: 0.6763 - learning_rate: 0.0010
# Epoch 8/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6596 - loss: 0.7840 - val_accuracy: 0.7035 - val_loss: 0.6912 - learning_rate: 0.0010
# Epoch 9/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6686 - loss: 0.7826 - val_accuracy: 0.7035 - val_loss: 0.6896 - learning_rate: 0.0010
# Epoch 10/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6774 - loss: 0.7670 - val_accuracy: 0.7109 - val_loss: 0.6699 - learning_rate: 0.0010
# Epoch 11/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6725 - loss: 0.7703 - val_accuracy: 0.7080 - val_loss: 0.6793 - learning_rate: 0.0010
# Epoch 12/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6697 - loss: 0.7747 - val_accuracy: 0.7035 - val_loss: 0.7004 - learning_rate: 0.0010
# Epoch 13/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6678 - loss: 0.7752 - val_accuracy: 0.7183 - val_loss: 0.6709 - learning_rate: 0.0010
# Epoch 14/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6773 - loss: 0.7516 - val_accuracy: 0.7065 - val_loss: 0.6749 - learning_rate: 0.0010
# Epoch 15/200
# 187/191 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6784 - loss: 0.7483
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6774 - loss: 0.7520 - val_accuracy: 0.7139 - val_loss: 0.6933 - learning_rate: 0.0010
# Epoch 16/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6909 - loss: 0.7317 - val_accuracy: 0.7080 - val_loss: 0.6656 - learning_rate: 5.0000e-04
# Epoch 17/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6957 - loss: 0.7215 - val_accuracy: 0.7286 - val_loss: 0.6485 - learning_rate: 5.0000e-04
# Epoch 18/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6978 - loss: 0.7286 - val_accuracy: 0.7168 - val_loss: 0.6616 - learning_rate: 5.0000e-04
# Epoch 19/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7024 - loss: 0.7168 - val_accuracy: 0.7227 - val_loss: 0.6543 - learning_rate: 5.0000e-04
# Epoch 20/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6896 - loss: 0.7271 - val_accuracy: 0.7124 - val_loss: 0.6754 - learning_rate: 5.0000e-04
# Epoch 21/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6989 - loss: 0.7130 - val_accuracy: 0.7286 - val_loss: 0.6719 - learning_rate: 5.0000e-04
# Epoch 22/200
# 184/191 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6893 - loss: 0.7271
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6948 - loss: 0.7238 - val_accuracy: 0.7050 - val_loss: 0.6812 - learning_rate: 5.0000e-04
# Epoch 23/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7001 - loss: 0.7159 - val_accuracy: 0.7080 - val_loss: 0.6667 - learning_rate: 2.5000e-04
# Epoch 24/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7086 - loss: 0.6945 - val_accuracy: 0.7242 - val_loss: 0.6526 - learning_rate: 2.5000e-04
# Epoch 25/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7096 - loss: 0.6942 - val_accuracy: 0.7286 - val_loss: 0.6503 - learning_rate: 2.5000e-04
# Epoch 26/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7076 - loss: 0.6944 - val_accuracy: 0.7345 - val_loss: 0.6438 - learning_rate: 2.5000e-04
# Epoch 27/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7091 - loss: 0.6984 - val_accuracy: 0.7301 - val_loss: 0.6510 - learning_rate: 2.5000e-04
# Epoch 28/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7181 - loss: 0.6853 - val_accuracy: 0.7212 - val_loss: 0.6483 - learning_rate: 2.5000e-04
# Epoch 29/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7175 - loss: 0.6817 - val_accuracy: 0.7286 - val_loss: 0.6529 - learning_rate: 2.5000e-04
# Epoch 30/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7162 - loss: 0.6800 - val_accuracy: 0.7330 - val_loss: 0.6516 - learning_rate: 2.5000e-04
# Epoch 31/200
# 186/191 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7261 - loss: 0.6759
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7234 - loss: 0.6849 - val_accuracy: 0.7227 - val_loss: 0.6463 - learning_rate: 2.5000e-04
# Epoch 32/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7201 - loss: 0.6794 - val_accuracy: 0.7330 - val_loss: 0.6357 - learning_rate: 1.2500e-04
# Epoch 33/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7239 - loss: 0.6620 - val_accuracy: 0.7375 - val_loss: 0.6377 - learning_rate: 1.2500e-04
# Epoch 34/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7309 - loss: 0.6506 - val_accuracy: 0.7389 - val_loss: 0.6399 - learning_rate: 1.2500e-04
# Epoch 35/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7316 - loss: 0.6571 - val_accuracy: 0.7242 - val_loss: 0.6428 - learning_rate: 1.2500e-04
# Epoch 36/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7291 - loss: 0.6568 - val_accuracy: 0.7345 - val_loss: 0.6395 - learning_rate: 1.2500e-04
# Epoch 37/200
# 187/191 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7311 - loss: 0.6339
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7272 - loss: 0.6540 - val_accuracy: 0.7330 - val_loss: 0.6389 - learning_rate: 1.2500e-04
# Epoch 38/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7319 - loss: 0.6559 - val_accuracy: 0.7360 - val_loss: 0.6391 - learning_rate: 6.2500e-05
# Epoch 39/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7313 - loss: 0.6555 - val_accuracy: 0.7316 - val_loss: 0.6421 - learning_rate: 6.2500e-05
# Epoch 40/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7381 - loss: 0.6403 - val_accuracy: 0.7257 - val_loss: 0.6430 - learning_rate: 6.2500e-05
# Epoch 41/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7360 - loss: 0.6400 - val_accuracy: 0.7286 - val_loss: 0.6432 - learning_rate: 6.2500e-05
# Epoch 42/200
# 185/191 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7265 - loss: 0.6417
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7363 - loss: 0.6342 - val_accuracy: 0.7271 - val_loss: 0.6411 - learning_rate: 6.2500e-05
# Epoch 43/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7375 - loss: 0.6511 - val_accuracy: 0.7271 - val_loss: 0.6432 - learning_rate: 3.1250e-05
# Epoch 44/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7327 - loss: 0.6394 - val_accuracy: 0.7301 - val_loss: 0.6414 - learning_rate: 3.1250e-05
# Epoch 45/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7352 - loss: 0.6382 - val_accuracy: 0.7316 - val_loss: 0.6422 - learning_rate: 3.1250e-05
# Epoch 46/200
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7339 - loss: 0.6458 - val_accuracy: 0.7257 - val_loss: 0.6414 - learning_rate: 3.1250e-05
# Epoch 47/200
# 189/191 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7299 - loss: 0.6275
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7334 - loss: 0.6349 - val_accuracy: 0.7316 - val_loss: 0.6378 - learning_rate: 3.1250e-05
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %%
plt.figure(figsize=(12, 4))

# Gráfica Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Evolución de la Precisión')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()

# Gráfica Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Evolución de la Pérdida (Error)')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()

plt.tight_layout()
plt.show()

# Comprobamos resultados
loss, final_acc = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nMejor precisión de MLP: {final_acc:.4f}")

# Predecimos los datos de test
y_pred_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1)

# Datos de aprendizaje
nombres_clases = label_encoder.inverse_transform([0, 1, 2, 3]) # Recupera 'A', 'B', 'C', 'D'
print("\nDatos del aprendizaje")
print(classification_report(y_test, y_pred, target_names=nombres_clases))

# Matriz de Confusión
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=nombres_clases, yticklabels=nombres_clases)
plt.title("Matriz de Confusión Multiclase")
plt.xlabel("Predicción del Modelo")
plt.ylabel("Realidad")
plt.show()
# Out:
# Mejor precisión de MLP: 0.7178
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Datos del aprendizaje
#               precision    recall  f1-score   support
#
#            A       0.67      0.83      0.74       357
#            B       0.64      0.56      0.59       436
#            C       0.68      0.73      0.70       442
#            D       0.90      0.77      0.83       459
#
#     accuracy                           0.72      1694
#    macro avg       0.72      0.72      0.72      1694
# weighted avg       0.73      0.72      0.72      1694
