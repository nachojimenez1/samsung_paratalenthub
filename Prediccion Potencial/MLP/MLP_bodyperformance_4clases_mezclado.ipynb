# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv('bodyPerformance.csv')

# Ingeniería de variables
df['bmi'] = df['weight_kg'] / ((df['height_cm'] / 100) ** 2)
df['relative_grip'] = df['gripForce'] / df['weight_kg']

# Cambiamos a enteros los datos de género
df['gender'] = df['gender'].map({'M': 1, 'F': 0})

# Dividimos entre datos y objetivo
X = df.drop('class', axis=1)
y = df['class']

# %%
df.dtypes
# Out:
# age                        float64
# gender                       int64
# height_cm                  float64
# weight_kg                  float64
# body fat_%                 float64
# diastolic                  float64
# systolic                   float64
# gripForce                  float64
# sit and bend forward_cm    float64
# sit-ups counts             float64
# broad jump_cm              float64
# class                       object
# bmi                        float64
# relative_grip              float64
# dtype: object

# %%
matriz_corr = df.drop(columns=['class']).corr()
plt.figure(figsize=(14, 10))
sns.heatmap(matriz_corr, 
            annot=True,
            fmt=".2f",
            cmap="coolwarm",
            vmin=-1, vmax=1,
            linewidths=0.5,
            square=True)
plt.title('Matriz de Correlación del Dataset Body Performance', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Cambiamos de categorico a enteros los objetivos
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Separamos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Escalamos los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Diseñamos la arquitectura de la red MLP
model = Sequential([
    Dense(1024, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    Dense(4, activation='softmax')
])
# Out:
# c:\Users\miguelmr\anaconda3\envs\general\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Modificamos el learning rate si se estanca el aprendizaje
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)

# Paramos si hay sobreajuste
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

# Entrenamos la red
history = model.fit(X_train_scaled,
                    y_train,
                    epochs=200,
                    batch_size=32,
                    validation_split=0.1,
                    callbacks=[reduce_lr, early_stop],
                    verbose=1)
# Out:
# Epoch 1/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5038 - loss: 1.2449 - val_accuracy: 0.5196 - val_loss: 1.0069 - learning_rate: 0.0010
# Epoch 2/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5743 - loss: 0.9630 - val_accuracy: 0.6604 - val_loss: 0.8043 - learning_rate: 0.0010
# Epoch 3/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6182 - loss: 0.8798 - val_accuracy: 0.7024 - val_loss: 0.7344 - learning_rate: 0.0010
# Epoch 4/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6276 - loss: 0.8553 - val_accuracy: 0.7034 - val_loss: 0.7277 - learning_rate: 0.0010
# Epoch 5/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6418 - loss: 0.8294 - val_accuracy: 0.7090 - val_loss: 0.7122 - learning_rate: 0.0010
# Epoch 6/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6518 - loss: 0.8156 - val_accuracy: 0.7034 - val_loss: 0.7079 - learning_rate: 0.0010
# Epoch 7/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6533 - loss: 0.8149 - val_accuracy: 0.7192 - val_loss: 0.6890 - learning_rate: 0.0010
# Epoch 8/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6523 - loss: 0.8014 - val_accuracy: 0.7118 - val_loss: 0.6965 - learning_rate: 0.0010
# Epoch 9/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6639 - loss: 0.7872 - val_accuracy: 0.7080 - val_loss: 0.6809 - learning_rate: 0.0010
# Epoch 10/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6723 - loss: 0.7791 - val_accuracy: 0.7127 - val_loss: 0.6810 - learning_rate: 0.0010
# Epoch 11/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6715 - loss: 0.7808 - val_accuracy: 0.7006 - val_loss: 0.7005 - learning_rate: 0.0010
# Epoch 12/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6782 - loss: 0.7695 - val_accuracy: 0.7174 - val_loss: 0.6776 - learning_rate: 0.0010
# Epoch 13/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6785 - loss: 0.7660 - val_accuracy: 0.7239 - val_loss: 0.6601 - learning_rate: 0.0010
# Epoch 14/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6788 - loss: 0.7660 - val_accuracy: 0.7248 - val_loss: 0.6682 - learning_rate: 0.0010
# Epoch 15/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6750 - loss: 0.7643 - val_accuracy: 0.7164 - val_loss: 0.6750 - learning_rate: 0.0010
# Epoch 16/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6815 - loss: 0.7541 - val_accuracy: 0.7220 - val_loss: 0.6718 - learning_rate: 0.0010
# Epoch 17/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6795 - loss: 0.7622 - val_accuracy: 0.7155 - val_loss: 0.6747 - learning_rate: 0.0010
# Epoch 18/200
# 296/302 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6818 - loss: 0.7527
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6808 - loss: 0.7622 - val_accuracy: 0.7108 - val_loss: 0.6904 - learning_rate: 0.0010
# Epoch 19/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6851 - loss: 0.7440 - val_accuracy: 0.7332 - val_loss: 0.6502 - learning_rate: 5.0000e-04
# Epoch 20/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6950 - loss: 0.7307 - val_accuracy: 0.7369 - val_loss: 0.6458 - learning_rate: 5.0000e-04
# Epoch 21/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6895 - loss: 0.7409 - val_accuracy: 0.7229 - val_loss: 0.6595 - learning_rate: 5.0000e-04
# Epoch 22/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6973 - loss: 0.7273 - val_accuracy: 0.7313 - val_loss: 0.6436 - learning_rate: 5.0000e-04
# Epoch 23/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6945 - loss: 0.7259 - val_accuracy: 0.7220 - val_loss: 0.6527 - learning_rate: 5.0000e-04
# Epoch 24/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7000 - loss: 0.7219 - val_accuracy: 0.7341 - val_loss: 0.6409 - learning_rate: 5.0000e-04
# Epoch 25/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7003 - loss: 0.7233 - val_accuracy: 0.7285 - val_loss: 0.6449 - learning_rate: 5.0000e-04
# Epoch 26/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7046 - loss: 0.7147 - val_accuracy: 0.7276 - val_loss: 0.6589 - learning_rate: 5.0000e-04
# Epoch 27/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7042 - loss: 0.7098 - val_accuracy: 0.7034 - val_loss: 0.6413 - learning_rate: 5.0000e-04
# Epoch 28/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7095 - loss: 0.7021 - val_accuracy: 0.7295 - val_loss: 0.6452 - learning_rate: 5.0000e-04
# Epoch 29/200
# 295/302 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7044 - loss: 0.6976
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7083 - loss: 0.6993 - val_accuracy: 0.7267 - val_loss: 0.6442 - learning_rate: 5.0000e-04
# Epoch 30/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7135 - loss: 0.6881 - val_accuracy: 0.7304 - val_loss: 0.6327 - learning_rate: 2.5000e-04
# Epoch 31/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7181 - loss: 0.6775 - val_accuracy: 0.7295 - val_loss: 0.6260 - learning_rate: 2.5000e-04
# Epoch 32/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7163 - loss: 0.6691 - val_accuracy: 0.7360 - val_loss: 0.6294 - learning_rate: 2.5000e-04
# Epoch 33/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7202 - loss: 0.6706 - val_accuracy: 0.7388 - val_loss: 0.6251 - learning_rate: 2.5000e-04
# Epoch 34/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7219 - loss: 0.6713 - val_accuracy: 0.7425 - val_loss: 0.6210 - learning_rate: 2.5000e-04
# Epoch 35/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7258 - loss: 0.6646 - val_accuracy: 0.7407 - val_loss: 0.6206 - learning_rate: 2.5000e-04
# Epoch 36/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7294 - loss: 0.6669 - val_accuracy: 0.7416 - val_loss: 0.6179 - learning_rate: 2.5000e-04
# Epoch 37/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7301 - loss: 0.6647 - val_accuracy: 0.7341 - val_loss: 0.6242 - learning_rate: 2.5000e-04
# Epoch 38/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7265 - loss: 0.6657 - val_accuracy: 0.7332 - val_loss: 0.6267 - learning_rate: 2.5000e-04
# Epoch 39/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7276 - loss: 0.6677 - val_accuracy: 0.7313 - val_loss: 0.6234 - learning_rate: 2.5000e-04
# Epoch 40/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7274 - loss: 0.6622 - val_accuracy: 0.7313 - val_loss: 0.6294 - learning_rate: 2.5000e-04
# Epoch 41/200
# 298/302 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7248 - loss: 0.6671
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7281 - loss: 0.6551 - val_accuracy: 0.7379 - val_loss: 0.6225 - learning_rate: 2.5000e-04
# Epoch 42/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7419 - loss: 0.6344 - val_accuracy: 0.7388 - val_loss: 0.6162 - learning_rate: 1.2500e-04
# Epoch 43/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7401 - loss: 0.6389 - val_accuracy: 0.7416 - val_loss: 0.6133 - learning_rate: 1.2500e-04
# Epoch 44/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7395 - loss: 0.6335 - val_accuracy: 0.7397 - val_loss: 0.6162 - learning_rate: 1.2500e-04
# Epoch 45/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7363 - loss: 0.6392 - val_accuracy: 0.7416 - val_loss: 0.6114 - learning_rate: 1.2500e-04
# Epoch 46/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7407 - loss: 0.6403 - val_accuracy: 0.7435 - val_loss: 0.6087 - learning_rate: 1.2500e-04
# Epoch 47/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7464 - loss: 0.6242 - val_accuracy: 0.7341 - val_loss: 0.6128 - learning_rate: 1.2500e-04
# Epoch 48/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7429 - loss: 0.6284 - val_accuracy: 0.7341 - val_loss: 0.6203 - learning_rate: 1.2500e-04
# Epoch 49/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7396 - loss: 0.6366 - val_accuracy: 0.7323 - val_loss: 0.6192 - learning_rate: 1.2500e-04
# Epoch 50/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7493 - loss: 0.6302 - val_accuracy: 0.7351 - val_loss: 0.6155 - learning_rate: 1.2500e-04
# Epoch 51/200
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7436 - loss: 0.6256
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7435 - loss: 0.6250 - val_accuracy: 0.7360 - val_loss: 0.6128 - learning_rate: 1.2500e-04
# Epoch 52/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7440 - loss: 0.6215 - val_accuracy: 0.7379 - val_loss: 0.6122 - learning_rate: 6.2500e-05
# Epoch 53/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7473 - loss: 0.6212 - val_accuracy: 0.7351 - val_loss: 0.6145 - learning_rate: 6.2500e-05
# Epoch 54/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7488 - loss: 0.6263 - val_accuracy: 0.7388 - val_loss: 0.6118 - learning_rate: 6.2500e-05
# Epoch 55/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7441 - loss: 0.6236 - val_accuracy: 0.7425 - val_loss: 0.6105 - learning_rate: 6.2500e-05
# Epoch 56/200
# 298/302 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7563 - loss: 0.6030
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7503 - loss: 0.6132 - val_accuracy: 0.7435 - val_loss: 0.6140 - learning_rate: 6.2500e-05
# Epoch 57/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7494 - loss: 0.6178 - val_accuracy: 0.7369 - val_loss: 0.6132 - learning_rate: 3.1250e-05
# Epoch 58/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7461 - loss: 0.6223 - val_accuracy: 0.7351 - val_loss: 0.6145 - learning_rate: 3.1250e-05
# Epoch 59/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7523 - loss: 0.6095 - val_accuracy: 0.7388 - val_loss: 0.6129 - learning_rate: 3.1250e-05
# Epoch 60/200
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7537 - loss: 0.6007 - val_accuracy: 0.7388 - val_loss: 0.6151 - learning_rate: 3.1250e-05
# Epoch 61/200
# 297/302 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7510 - loss: 0.6113
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7460 - loss: 0.6166 - val_accuracy: 0.7397 - val_loss: 0.6170 - learning_rate: 3.1250e-05
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 46.

# %%
plt.figure(figsize=(12, 4))

# Gráfica Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Evolución de la Precisión')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()

# Gráfica Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Evolución de la Pérdida (Error)')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()

plt.tight_layout()
plt.show()

# Comprobamos resultados
loss, final_acc = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nMejor precisión de MLP: {final_acc:.4f}")

# Predecimos los datos de test
y_pred_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1)

# Datos de aprendizaje
nombres_clases = label_encoder.inverse_transform([0, 1, 2, 3]) # Recupera 'A', 'B', 'C', 'D'
print("\nDatos del aprendizaje")
print(classification_report(y_test, y_pred, target_names=nombres_clases))

# Matriz de Confusión
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=nombres_clases, yticklabels=nombres_clases)
plt.title("Matriz de Confusión Multiclase")
plt.xlabel("Predicción del Modelo")
plt.ylabel("Realidad")
plt.show()
# Out:
# Mejor precisión de MLP: 0.7507
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Datos del aprendizaje
#               precision    recall  f1-score   support
#
#            A       0.73      0.89      0.80       685
#            B       0.64      0.59      0.61       662
#            C       0.71      0.70      0.71       650
#            D       0.94      0.82      0.88       682
#
#     accuracy                           0.75      2679
#    macro avg       0.75      0.75      0.75      2679
# weighted avg       0.76      0.75      0.75      2679
